# %%
from wildlife_datasets import analysis, datasets, loader

# %%
datasets.AerialCattle2017.get_data('data/AerialCattle2017')
# Out:
# DATASET AerialCattle2017: DOWNLOADING STARTED.
# You are trying to download an already downloaded dataset.
#         This message may have happened to due interrupted download or extract.
#         To force the download use the `force=True` keyword such as
#         get_data(..., force=True) or download(..., force=True).

# %%
d = datasets.AerialCattle2017('data/AerialCattle2017')
d.plot_grid()

# %%
datasets.CTai.get_data('data/CTai')
# Out:
# DATASET CTai: DOWNLOADING STARTED.
# You are trying to download an already downloaded dataset.
#         This message may have happened to due interrupted download or extract.
#         To force the download use the `force=True` keyword such as
#         get_data(..., force=True) or download(..., force=True).

# %%
d = datasets.CTai('data/CTai')
d.plot_grid()

# %%
datasets.FriesianCattle2015.get_data('data/FriesianCattle2015')
# Out:
# DATASET FriesianCattle2015: DOWNLOADING STARTED.
# You are trying to download an already downloaded dataset.
#         This message may have happened to due interrupted download or extract.
#         To force the download use the `force=True` keyword such as
#         get_data(..., force=True) or download(..., force=True).

# %%
d = datasets.FriesianCattle2015('data/FriesianCattle2015')
d.plot_grid()
# Out:
# This dataset is outdated. You may want to call a newer version such as FriesianCattle2015v2.

# %%
datasets.MacaqueFaces.get_data('data/MacaqueFaces')
# Out:
# DATASET MacaqueFaces: DOWNLOADING STARTED.
# You are trying to download an already downloaded dataset.
#         This message may have happened to due interrupted download or extract.
#         To force the download use the `force=True` keyword such as
#         get_data(..., force=True) or download(..., force=True).

# %%
datasets.Cows2021.get_data('data/Cows2021')
# Out:
# DATASET Cows2021: DOWNLOADING STARTED.
# 4vnrca7qw1642qlwxjadp87h7.zip:   0%|          | 3.24M/18.9G [00:42<69:20:49, 75.6kB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 datasets.Cows2021.get_data('data/Cows2021')
#
# File c:\Users\nraji\tfod\lib\site-packages\wildlife_datasets\datasets\datasets.py:78, in DatasetFactory.get_data(cls, root, force, **kwargs)
#      76 else:
#      77     print('DATASET %s: DOWNLOADING STARTED.' % dataset_name)
# ---> 78     cls.download(root, force=force, **kwargs)
#      79     print('DATASET %s: EXTRACTING STARTED.' % dataset_name)
#      80     cls.extract(root,  **kwargs)
#
# File c:\Users\nraji\tfod\lib\site-packages\wildlife_datasets\datasets\datasets.py:96, in DatasetFactory.download(cls, root, force, **kwargs)
#      94     os.remove(mark_file_name)
#      95 with utils.data_directory(root):
# ...
